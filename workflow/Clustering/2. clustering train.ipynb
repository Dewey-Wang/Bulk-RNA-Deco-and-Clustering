# %%
import sys
from pathlib import Path
import os
# add project root to Python path
project_root = Path("..").resolve()
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))
    
from scripts.train_clustering import run_ensemble_arbiter, load_full
IN_DIR = "./outputs_features_csv/"
FILES = {"Combined (z-score)": "features.csv"}
GROUP_COL = "Sample"

# ---------------- Main ----------------
for name, fname in FILES.items():
        print(f"\n=== Ensemble Arbiter (LR arbiter, 3-way: LGBM/KNN/RIDGE; GroupKFold by '{GROUP_COL}', leakage-free) — {name} ===")
        df = load_full(os.path.join(IN_DIR, fname))
        pred_1 = run_ensemble_arbiter(df, fname, base_models=("lgbm","knn","ridge"),
                         cv_mode="stratified", cv_shuffle=True, cv_random_state=42)
        pred_2 = run_ensemble_arbiter(df, fname, base_models=("lgbm","knn","ridge"),
                         cv_mode="kfold", cv_shuffle=True, cv_random_state=42)
        pred_3 = run_ensemble_arbiter(df, fname, base_models=("ridge","lgbm"),
                         cv_mode="group")
# Out:
# === Ensemble Arbiter (LR arbiter, 3-way: LGBM/KNN/RIDGE; GroupKFold by 'Sample', leakage-free) — Combined (z-score) ===
# features.csv: StratifiedKFold (5 folds, shuffle=True, seed=42).
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] Number of positive: 13340, number of negative: 12559
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004473 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42218
# [LightGBM] [Info] Number of data points in the train set: 25899, number of used features: 101
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499973 -> initscore=-0.000108
# [LightGBM] [Info] Start training from score -0.000108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# /opt/anaconda3/envs/ml4g-project2/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /opt/anaconda3/envs/ml4g-project2/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42218
# [LightGBM] [Info] Number of data points in the train set: 25899, number of used features: 101
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] Start training from score -2.178453
# [LightGBM] [Info] Start training from score -2.362116
# [LightGBM] [Info] Start training from score -2.178800
# [LightGBM] [Info] Start training from score -2.178062
# [LightGBM] [Info] Start training from score -2.178311
# [LightGBM] [Info] Start training from score -2.177709
# [LightGBM] [Info] Start training from score -2.179035
# [LightGBM] [Info] Start training from score -2.178266
# [LightGBM] [Info] Start training from score -2.178572
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/ml4g-project2/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# /opt/anaconda3/envs/ml4g-project2/lib/python3.11/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] Number of positive: 13340, number of negative: 12559
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004560 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 42218
# [LightGBM] [Info] Number of data points in the train set: 25899, number of used features: 101
# [LightGBM] [Warning] bagging_freq is set=10, subsample_freq=0 will be ignored. Current value: bagging_freq=10
# [LightGBM] [Warning] feature_fraction is set=0.6154, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6154
# [LightGBM] [Warning] bagging_fraction is set=0.9876, subsample=1.0 will be ignored. Current value: bagging_fraction=0.9876
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499973 -> initscore=-0.000108
# [LightGBM] [Info] Start training from score -0.000108
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
from scripts.train_clustering import combine_pred_triplet

combined = combine_pred_triplet(pred_1, pred_2, pred_3,
                                id_col="cell_id",
                                col_name="pred_final")

# 看看結果
print(combined.head())

# 若只想要最後的 (cell_id, pred_final)
final_submission = combined[[ "cell_id", "final_pred" ]].rename(columns={"final_pred":"pred_final"})
# Out:
# [Tie 2-different] cell_id=AAAGGTAGTCGTCAGC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AACAACCTCTAGACCA-1_5 | pred_1=T, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=AACAGGGTCACTGTTT-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=AACGTCAAGCGTTACT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AAGTCGTGTTAAGAAC-1_10 | pred_1=Fibroblast, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=AAGTGAATCCAAGCCG-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AAGTTCGCAAATTGCC-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=AATCACGGTGCCTGAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AATGGAACACCCTAGG-1_6 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=ACAAGCTAGCATCAGG-1_9 | pred_1=Endothelial, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=ACAGCCGGTAAGAACT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACATCGACAACTCCCT-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACATTTCTCGCTTACC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACCAACAGTCACTCGG-1_5 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=ACCACAACAGAGTTCT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACCATTTGTAGTTAGA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=ACCATTTGTTTAGACC-1_9 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=ACCATTTGTTTCGACA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACCTACCTCAGGCGAA-1_9 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACGATCACAATTGGTC-1_9 | pred_1=Plasmablast, pred_2=Plasmablast, pred_3=Endothelial -> use Plasmablast
# [Tie 2-different] cell_id=ACGATGTTCAGACCGC-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=ACGTAGTCACCTGTCT-1_5 | pred_1=T, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=ACGTCCTCAACCTATG-1_10 | pred_1=Myofibroblast, pred_2=Endothelial, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=ACTATGGGTAGTCCTA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ACTGTCCCATGTGACT-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Mast -> use Myofibroblast
# [Tie 2-different] cell_id=ACTGTCCTCGGCTTGG-1_10 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=B -> use Fibroblast
# [Tie 2-different] cell_id=ACTTTCACAAGAAATC-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Endothelial -> use Myofibroblast
# [Tie 2-different] cell_id=AGAACAATCTTCGATT-1_10 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=AGAAGCGAGTCCCAGC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AGACACTCAAGGCTTT-1_10 | pred_1=Myeloid, pred_2=Myeloid, pred_3=Myofibroblast -> use Myeloid
# [Tie 2-different] cell_id=AGAGAATCACCCATAA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=AGAGCCCGTATCGGTT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AGATGCTAGTTCATGC-1_10 | pred_1=B, pred_2=B, pred_3=NK -> use B
# [Tie 2-different] cell_id=AGCCAATGTCAGTTTG-1_10 | pred_1=T, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=AGCCAGCTCGTAATGC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AGCGCTGGTACTAACC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AGGGTGAAGTTGAAGT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=AGGTCTACATGGCCCA-1_9 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=AGTAACCGTGTGTCCG-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=AGTCACACAAGATTGA-1_6 | pred_1=Myeloid, pred_2=Myeloid, pred_3=B -> use Myeloid
# [Tie 2-different] cell_id=ATACTTCCACTCCGAG-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=ATATCCTGTACCAGAG-1_10 | pred_1=T, pred_2=T, pred_3=Endothelial -> use T
# [Tie 2-different] cell_id=ATCGTAGAGGGCGAAG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ATGGGAGAGAAACTAC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ATGGGTTAGAGGTGCT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ATGGGTTGTCTACAAC-1_9 | pred_1=Endothelial, pred_2=Endothelial, pred_3=NK -> use Endothelial
# [Tie 2-different] cell_id=ATGGGTTGTGATGTAA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=ATGGTTGCACACGGAA-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=ATGTCCCGTGACACAG-1_9 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=ATGTCCCTCAAGCCGC-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CAACAACCAAGGATGC-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CAACAGTTCCGTGTGG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CAACCAATCCCTGTTG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CAACCTCAGCGGGTAT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CAAGCTACAGAACATA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CACACAAGTCACGACC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CAGATCATCTTCTAAC-1_5 | pred_1=Endothelial, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=CAGCAATAGAGGGCGA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CAGCGTGCATGCGTGC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CAGGTATCACGCACCA-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CAGTGCGCAGAAGTTA-1_10 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CAGTGCGGTCGATTAC-1_9 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CATCCGTTCCGCAGTG-1_9 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=CATGGTAAGCGCCCAT-1_10 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CATTCCGTCCCTTTGG-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CATTCTAAGACTACGG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CATTGAGAGGATACCG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCACACTCAGGCCCTA-1_6 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CCACACTTCGGCCCAA-1_9 | pred_1=Mast, pred_2=Fibroblast, pred_3=Mast -> use Mast
# [Tie 2-different] cell_id=CCACCATAGGCAGGTT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCACGAGGTTAGAAGT-1_9 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=CCATAAGCAGTTAAAG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCATAAGCATGCGGTC-1_10 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CCCTCAAAGACGAGCT-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCCTCAAAGCTCCATA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCCTCTCAGTGAGGTC-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CCGAACGTCGTTCATT-1_10 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CCGCAAGAGAAATGGG-1_9 | pred_1=NK, pred_2=NK, pred_3=T -> use NK
# [Tie 2-different] cell_id=CCGGACATCGTGTTCC-1_9 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CCGGGTACAGTAGAAT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CCTCTCCTCTGGCCTT-1_6 | pred_1=NK, pred_2=T, pred_3=T -> use T
# [Tie 2-different] cell_id=CCTTTGGTCGACGAGA-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CGAATTGGTGGCTGCT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CGACAGCGTAATCAAG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CGAGTGCTCAAGATAG-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CGCATGGGTAACGCGA-1_10 | pred_1=T, pred_2=T, pred_3=Endothelial -> use T
# [Tie 2-different] cell_id=CGCCAGAGTCATGCAT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CGCCATTGTTGTGCAT-1_5 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CGGGTCAGTAGGTAGC-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CGGGTCATCACCATGA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CGTAATGAGGCTCTAT-1_9 | pred_1=Fibroblast, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=CGTAATGTCGTCACCT-1_5 | pred_1=Myeloid, pred_2=Myeloid, pred_3=T -> use Myeloid
# [Tie 2-different] cell_id=CGTGCTTTCCGCCTAT-1_10 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CTAACCCGTGGATCAG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTACATTCATCCGGCA-1_5 | pred_1=NK, pred_2=NK, pred_3=Endothelial -> use NK
# [Tie 2-different] cell_id=CTAGGTATCTCCACTG-1_9 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CTATCTATCATACGAC-1_9 | pred_1=Mast, pred_2=Mast, pred_3=Endothelial -> use Mast
# [Tie 2-different] cell_id=CTCAATTTCCACGAAT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTCACTGAGTGATAAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTCACTGTCCACTGAA-1_10 | pred_1=NK, pred_2=Fibroblast, pred_3=Fibroblast -> use Fibroblast
# [Tie 2-different] cell_id=CTCATTATCAACCGAT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTCCACATCGCTGTCT-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTCCATGGTCGTGGAA-1_6 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=CTCCCAACAACCGCCA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CTCCCTCTCCAATCTT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CTCCTCCTCGAACCAT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 3-different] cell_id=CTCCTTTGTCCTATAG-1_10 | pred_1=Endothelial, pred_2=Fibroblast, pred_3=Myofibroblast -> use pred_1
# [Tie 2-different] cell_id=CTCTCGATCCCTCAAC-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=CTGAGGCGTACCTAAC-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTGATCCAGGAACGAA-1_6 | pred_1=T, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=CTGCAGGTCTCTCTTC-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=CTGCATCAGGGTCAAC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTGGACGGTTACGTAC-1_6 | pred_1=Myofibroblast, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=CTGGACGTCCTCGCAT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTTACCGAGTAAGGGA-1_10 | pred_1=B, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=CTTGAGAGTACCACGC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=CTTGATTGTCCAGCAC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GAACGTTCACAGGATG-1_10 | pred_1=T, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=GAAGAATTCAACACGT-1_9 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GAAGGACGTGGCTGCT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GAAGGACTCGACCACG-1_9 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GAAGGGTCACCAAATC-1_5 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=GAATCGTGTCCACGCA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GACACGCTCGAAGGAC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GACCGTGCACGGCGTT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GACTCAATCCGATCTC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GAGAAATTCGAGAACG-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GAGATGGCAGCTCGGT-1_5 | pred_1=Mast, pred_2=Mast, pred_3=Myeloid -> use Mast
# [Tie 2-different] cell_id=GAGTGAGGTAAGATCA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GAGTGTTCAAACCACT-1_9 | pred_1=Endothelial, pred_2=Fibroblast, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=GATCAGTAGTTCCGTA-1_5 | pred_1=NK, pred_2=T, pred_3=T -> use T
# [Tie 2-different] cell_id=GATCCCTCACACCAGC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GATTCTTCACTAGTAC-1_10 | pred_1=Fibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Fibroblast
# [Tie 2-different] cell_id=GCAACATGTACTGGGA-1_6 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GCATGATGTGAGATTA-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GCCAGTGCAGCTGTGC-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=GCCAGTGTCGAAATCC-1_6 | pred_1=NK, pred_2=T, pred_3=T -> use T
# [Tie 2-different] cell_id=GCCATGGCAGGGAGAG-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GCTCAAAGTATCTTCT-1_6 | pred_1=T, pred_2=T, pred_3=Plasmablast -> use T
# [Tie 2-different] cell_id=GGAGATGAGACTACGG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GGAGATGGTAACCCTA-1_6 | pred_1=Myofibroblast, pred_2=T, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=GGAGATGTCCCTTGTG-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GGAGGTAGTTGGGACA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GGCAGTCAGCCTGCCA-1_6 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GGCTGTGCAAGTGCTT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GGGACCTCAGACAATA-1_6 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=GGGATGAAGCCAGACA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GGGTATTCAGCTGTTA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GGGTGTCTCTAGGCCG-1_10 | pred_1=Mast, pred_2=Myofibroblast, pred_3=Mast -> use Mast
# [Tie 2-different] cell_id=GGGTTTAAGGTAGTCG-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GGTGAAGAGGTTACAA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GGTTCTCCAATGAGCG-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTAACCACACTCCACT-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTAACCATCCTTCTAA-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GTAATGCAGGTTTGAA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTAGAGGAGTAGACCG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTAGAGGGTAAGGCTG-1_10 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=GTAGATCAGCACCGTC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTCATCCGTCTGATAC-1_5 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GTCGTTCAGGATAATC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTCTACCTCGAGCTGC-1_5 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GTCTTTAAGCAGGCTA-1_10 | pred_1=Myofibroblast, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=GTGATGTAGATGCTGG-1_5 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GTGATGTTCTTAGGAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=GTGGGAAAGCCAAGTG-1_6 | pred_1=T, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=GTGGTTATCGTCCTCA-1_9 | pred_1=Myofibroblast, pred_2=Fibroblast, pred_3=Fibroblast -> use Fibroblast
# [Tie 2-different] cell_id=GTGTCCTTCTTCGCTG-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=GTTGTCCTCTGCTTAT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=GTTTACTTCAGGCGAA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TAAGCACGTCACCGAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TACACCCAGACTGGGT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TACCCACGTCTTGAAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TACCCGTTCGCTTGAA-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Mast -> use Myofibroblast
# [Tie 2-different] cell_id=TACCGAATCTTGTGCC-1_5 | pred_1=Myofibroblast, pred_2=T, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TACGTCCCAGCTTTGA-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TACTGCCCAATCGAAA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TACTTGTAGTGCCCGT-1_9 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TAGATCGTCGAAGGAC-1_9 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TAGGTTGGTTGTAGCT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TATGTTCCATCTCAAG-1_5 | pred_1=Myofibroblast, pred_2=Fibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TCAGCCTGTCCCACGA-1_10 | pred_1=NK, pred_2=T, pred_3=T -> use T
# [Tie 2-different] cell_id=TCAGGGCGTCACTCTC-1_9 | pred_1=T, pred_2=B, pred_3=B -> use B
# [Tie 2-different] cell_id=TCAGGTAAGCACTCTA-1_10 | pred_1=Fibroblast, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TCAGGTAGTTGCATTG-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCAGTGAAGGTAAGTT-1_9 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TCATCATAGCAGAAAG-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TCATCATCATCATGAC-1_9 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TCATGCCCAGGGAGAG-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCATGTTGTGCAGGAT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCATTACAGTCTTCGA-1_5 | pred_1=Myofibroblast, pred_2=Fibroblast, pred_3=Fibroblast -> use Fibroblast
# [Tie 2-different] cell_id=TCATTACTCGGAAGGT-1_9 | pred_1=B, pred_2=B, pred_3=Mast -> use B
# [Tie 2-different] cell_id=TCATTCACAGAACTAA-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCATTGTAGCCTGTGC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCATTTGCACCAATTG-1_10 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCCATGCGTCTCGGAC-1_10 | pred_1=B, pred_2=Endothelial, pred_3=B -> use B
# [Tie 2-different] cell_id=TCCCACAAGTTGTAAG-1_10 | pred_1=Myofibroblast, pred_2=Mast, pred_3=Mast -> use Mast
# [Tie 2-different] cell_id=TCCGAAACACATCATG-1_9 | pred_1=Fibroblast, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=TCCGAAATCGGCACTG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCCTAATAGACCTTTG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCCTAATCACGCAGTC-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TCCTTCTGTAGGAGGG-1_10 | pred_1=Myofibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TCCTTTCGTCCGTACG-1_10 | pred_1=Fibroblast, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=TCGAACATCTGGCCTT-1_9 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TCGGTCTAGAGAGTGA-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TCTACCGCATGAAGCG-1_5 | pred_1=T, pred_2=NK, pred_3=T -> use T
# [Tie 2-different] cell_id=TCTTAGTCAATTCTTC-1_9 | pred_1=Plasmablast, pred_2=Endothelial, pred_3=Endothelial -> use Endothelial
# [Tie 2-different] cell_id=TGAATCGAGGCCCGTT-1_5 | pred_1=Myofibroblast, pred_2=NK, pred_3=NK -> use NK
# [Tie 2-different] cell_id=TGAATGCAGAGTCCGA-1_10 | pred_1=Fibroblast, pred_2=B, pred_3=Fibroblast -> use Fibroblast
# [Tie 2-different] cell_id=TGACAGTAGCAGGCAT-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TGAGGAGGTGCAACAG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TGATTCTGTTCTTGCC-1_6 | pred_1=Plasmablast, pred_2=Plasmablast, pred_3=Myofibroblast -> use Plasmablast
# [Tie 2-different] cell_id=TGCATCCTCATTGCGA-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TGCATGAAGACGCCCT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TGCCGAGAGGCTAACG-1_6 | pred_1=Plasmablast, pred_2=B, pred_3=B -> use B
# [Tie 2-different] cell_id=TGCTTGCGTAGGTTTC-1_9 | pred_1=NK, pred_2=T, pred_3=T -> use T
# [Tie 2-different] cell_id=TGGTACATCAGATGCT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TGTTCATGTTATTCCT-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TGTTTGTGTCTACTGA-1_10 | pred_1=Myofibroblast, pred_2=T, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TTAATCCTCGGTCACG-1_6 | pred_1=NK, pred_2=T, pred_3=NK -> use NK
# [Tie 2-different] cell_id=TTACGTTCAGCATTGT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTACTGTTCTCTTAAC-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTAGTCTTCCGAGGCT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTCCAATGTTCAAAGA-1_10 | pred_1=Fibroblast, pred_2=Myofibroblast, pred_3=Fibroblast -> use Fibroblast
# [Tie 2-different] cell_id=TTCGGTCAGGCTGGAT-1_6 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TTCTAACAGAATTGTG-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTCTAACTCGCTGTTC-1_10 | pred_1=Endothelial, pred_2=Myofibroblast, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TTCTCTCGTCAAACGG-1_6 | pred_1=B, pred_2=B, pred_3=Myofibroblast -> use B
# [Tie 2-different] cell_id=TTCTTCCTCTGAGATC-1_6 | pred_1=Plasmablast, pred_2=Plasmablast, pred_3=B -> use Plasmablast
# [Tie 2-different] cell_id=TTCTTGAAGATGGCAC-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 3-different] cell_id=TTCTTGAGTCCTTTGC-1_10 | pred_1=T, pred_2=Endothelial, pred_3=NK -> use pred_1
# [Tie 2-different] cell_id=TTGAGTGGTCTTGAGT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTGATGGGTATGAAGT-1_6 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTGGGATAGGAACGAA-1_6 | pred_1=NK, pred_2=NK, pred_3=T -> use NK
# [Tie 2-different] cell_id=TTGTTTGAGGTGCCTC-1_5 | pred_1=T, pred_2=T, pred_3=Myofibroblast -> use T
# [Tie 2-different] cell_id=TTTCGATAGGTCCCGT-1_5 | pred_1=T, pred_2=T, pred_3=NK -> use T
# [Tie 2-different] cell_id=TTTCGATCATGTAACC-1_6 | pred_1=Myofibroblast, pred_2=T, pred_3=Myofibroblast -> use Myofibroblast
# [Tie 2-different] cell_id=TTTCGATTCCTGTTAT-1_5 | pred_1=NK, pred_2=NK, pred_3=Myofibroblast -> use NK
# [Tie 2-different] cell_id=TTTGTTGGTGGAAATT-1_6 | pred_1=T, pred_2=T, pred_3=B -> use T
# [Tie 2-different] cell_id=TTTGTTGGTTAATGAG-1_6 | pred_1=Myofibroblast, pred_2=T, pred_3=Myofibroblast -> use Myofibroblast
#                  cell_id       pred_1       pred_2       pred_3   final_pred
# 0   AAACCCAAGACAGTCG-1_9            T            T            T            T
# 1   AAACCCAAGGAGGCAG-1_5            T            T            T            T
# 2  AAACCCAAGGCCATAG-1_10  Plasmablast  Plasmablast  Plasmablast  Plasmablast
# 3   AAACCCAAGGCTATCT-1_6   Fibroblast   Fibroblast   Fibroblast   Fibroblast
# 4   AAACCCAAGTTGCGCC-1_5            T            T            T            T

# %%
# Jupyter cell: build cluster_membership.csv from in-memory `pred` only
import os
import re
import pandas as pd
import scanpy as sc

# ---- Settings ----
TEST_AD_PATH     = "../../Dataset/test_data/test_adata.h5ad"
OUT_DIR = "./prediction/"
OUT_CLUSTER_CSV = os.path.join(OUT_DIR, "cluster_membership.csv")

STRIP_TEST_SUFFIX = True  # True: 比對前移除 cell_id 結尾的 "-test"

# ---- Guards ----
if "pred" not in globals() or not isinstance(final_submission, pd.DataFrame):
    raise RuntimeError("需要記憶體中的 DataFrame `pred`（含 columns: cell_id, pred_final）。")

need_cols = {"cell_id", "pred_final"}
missing = need_cols - set(final_submission.columns)
if missing:
    raise ValueError(f"`pred` 缺少欄位: {missing}. 需要 {need_cols}")

df_pred = final_submission[list(need_cols)].copy()

# ---- Normalize cell_id for matching ----
if STRIP_TEST_SUFFIX:
    df_pred["cell_id_std"] = df_pred["cell_id"].astype(str).str.replace(r"-test$", "", regex=True)
else:
    df_pred["cell_id_std"] = df_pred["cell_id"].astype(str)

# ---- Load test obs order ----
ad_te = sc.read_h5ad(TEST_AD_PATH)
test_order = pd.Index(ad_te.obs_names.astype(str))

# ---- Align & reorder to test order ----
pred_idx = pd.Index(df_pred["cell_id_std"])
common   = test_order.intersection(pred_idx)
if common.empty:
    raise ValueError("pred 的 cell_id 與 test obs_names 沒有交集（檢查 -test 尾碼或命名）。")

df_pred_idxed = (
    df_pred.set_index("cell_id_std", drop=False)
           .loc[common, ["cell_id", "pred_final"]]
           .rename_axis("cell_id_std")
           .reset_index(drop=True)
)
# 使輸出的 cell_id 與 test 完全一致（不帶 '-test'）
df_pred_idxed["cell_id"] = common.values

if len(common) < len(test_order):
    missing_n = len(test_order) - len(common)
    print(f"[Info] test n={len(test_order)}，pred 可對齊 n={len(common)}；缺少 {missing_n} 列未在 pred 中。")

# ---- Build cluster mapping (1..K) ----
labels = df_pred_idxed["pred_final"].astype(str)
uniq_labels = sorted(labels.unique().tolist())

use_order = None
if use_order is None:
    use_order = uniq_labels  # 字母序穩定

label_to_cluster = {lab: i+1 for i, lab in enumerate(use_order)}  # 1..K

# ---- Compose and save cluster_membership ----
df_cluster = pd.DataFrame({
    "index": df_pred_idxed["cell_id"].values,                           # 與 test obs_names 完全一致的順序
    "cluster": labels.map(label_to_cluster).astype(int).values
})
if df_cluster["index"].duplicated().any():
    raise ValueError("cluster_membership 中 index 出現重複，請檢查。")
if (df_cluster["cluster"] <= 0).any():
    raise ValueError("cluster 必須為正整數（>=1）。")

df_cluster.to_csv(OUT_CLUSTER_CSV, index=True)  # 依你的示例，保留 pandas 行索引
print(f"[OK] wrote cluster_membership: {OUT_CLUSTER_CSV} | rows={len(df_cluster)}")

print("\n(label -> cluster) mapping:")
print(pd.Series(label_to_cluster).to_string())

print("\n[cluster_membership head]")
print(df_cluster.head(10).to_csv(index=True))
# Out:
# [OK] wrote cluster_membership: ./result_final/cluster_membership.csv | rows=18616
#
# (label -> cluster) mapping:
# B                1
# Endothelial      2
# Fibroblast       3
# Mast             4
# Myeloid          5
# Myofibroblast    6
# NK               7
# Plasmablast      8
# T                9
#
# [cluster_membership head]
# ,index,cluster
# 0,AAACCCAAGGAGGCAG-1_5,9
# 1,AAACCCAAGTTGCGCC-1_5,9
# 2,AAACCCACACGGATCC-1_5,9
# 3,AAACCCACATCGGAAG-1_5,9
# 4,AAACCCAGTGCGAGTA-1_5,9
# 5,AAACCCATCACGAACT-1_5,9
# 6,AAACGAAAGTAGAATC-1_5,9
# 7,AAACGAACAGAGATGC-1_5,9
# 8,AAACGAATCAAGAATG-1_5,3
# 9,AAACGAATCCACAAGT-1_5,7
